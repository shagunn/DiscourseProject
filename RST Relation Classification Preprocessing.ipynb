# %%
from __future__ import print_function
import educe.rst_dt
from educe.corpus import FileId

# relative to the educe docs directory
data_dir = '../data'
rst_corpus_dir = '{dd}/rst_discourse_treebank/data/RSTtrees-WSJ-main-1.0/TEST/'.format(dd=data_dir)

# read and load the documents from the WSJ main directory which were tagged
rst_reader = educe.rst_dt.Reader(rst_corpus_dir)
rst_corpus = rst_reader.slurp(verbose=True)
# Out:
# Slurping corpus dir [38/38 done]

# %%
#open a file to output parsed EDU pairs and corresponding relations
import json
import csv
data = {}

f = open('training_data_new.csv', 'w')
writer = csv.writer(f, delimiter = "|")

#set header in the csv file 
header = ['Filename', 'EDU1', 'EDU2', 'Relation']
writer.writerow([g for g in header])

# %%
#obtain subtrees and context for each key
for key in rst_corpus.keys():
    ex_key=educe.rst_dt.mk_key(key.doc)
    ex_doc = rst_corpus[ex_key]
    ex_context = ex_doc.label().context
    
    #go through all subtrees and extract relations and edus
    for ex_subtree in ex_doc.subtrees():
        subtree = educe.rst_dt.SimpleRSTTree.from_rst_tree(ex_subtree)
        
        #extract relation
        relation=subtree.label().rel
        satellite = []
        
        #extract edus
        if (relation!='leaf'):
            edus = subtree.leaves()
            nucleus = str(edus[0])
            
            #append all satellites together
            for edu in edus[1:]:
                satellite.append(str(edu).split(")")[1])
            
            #format the first and second text spans
            satellites =''.join(satellite)
            satellites = satellites.replace('\n', ' ')
            nucleus = nucleus.split(")")[1]
            nucleus = nucleus.replace('\n', ' ')
            
            #append the row to the csv file
            writer.writerow([key.doc, nucleus, satellites, relation])

# %%
import pandas as pd
import numpy as np

# %%
#load the data collected from the discourse trees
df = pd.read_csv('training_data_new.csv', delimiter='|')
df
# Out:
#           Filename                                               EDU1  \
# 0     wsj_0632.out   General Motors Corp. and Ford Motor Co. are n...
# 1     wsj_0632.out   General Motors Corp. and Ford Motor Co. are n...
# 2     wsj_0632.out   General Motors Corp. and Ford Motor Co. are n...
# 3     wsj_0632.out   General Motors Corp. and Ford Motor Co. are n...
# 4     wsj_0632.out   General Motors Corp. and Ford Motor Co. are n...
# 5     wsj_0632.out   as GM got early clearance from the Federal Tr...
# 6     wsj_0632.out                                GM confirmed Friday
# 7     wsj_0632.out                                GM confirmed Friday
# 8     wsj_0632.out                                GM confirmed Friday
# 9     wsj_0632.out   that it received permission late Thursday fro...
# 10    wsj_0632.out                    and on Friday, Jaguar announced
# 11    wsj_0632.out                    and on Friday, Jaguar announced
# 12    wsj_0632.out   A spokesman for GM, the No. 1 auto maker, dec...
# 13    wsj_0632.out   In late trading Friday, Jaguar shares bucked ...
# 14    wsj_0632.out   In late trading Friday, Jaguar shares bucked ...
# 15    wsj_0632.out   In late trading Friday, Jaguar shares bucked ...
# 16    wsj_0632.out                   and rose five pence to 725 pence
# 17    wsj_0632.out   In the U.S., Jaguar's American depositary rec...
# 18    wsj_0632.out                                    Analysts expect
# 19    wsj_0632.out   that the two U.S. auto giants will move quick...
# 20    wsj_0632.out   British government restrictions prevent any s...
# 21    wsj_0632.out   British government restrictions prevent any s...
# 22    wsj_0632.out   British government restrictions prevent any s...
# 23    wsj_0632.out   British government restrictions prevent any s...
# 24    wsj_0632.out   British government restrictions prevent any s...
# 25    wsj_0632.out                            The British government,
# 26    wsj_0632.out                            The British government,
# 27    wsj_0632.out   With the golden share as protection, Jaguar o...
# 28    wsj_0632.out                    Jaguar officials have indicated
# 29    wsj_0632.out                    Jaguar officials have indicated
# ...            ...                                                ...
# 2176  wsj_1387.out                       But the press kept it alive;
# 2177  wsj_1387.out   as with the Recruit scandal, lists began circ...
# 2178  wsj_1387.out   Within a matter of weeks, less-conservative m...
# 2179  wsj_1387.out   Within a matter of weeks, less-conservative m...
# 2180  wsj_1387.out     So far, though, there have been no allegations
# 2181  wsj_1387.out                             that the contributions
# 2182  wsj_1387.out                             that the contributions
# 2183  wsj_1387.out                 Then the two camps upped the ante:
# 2184  wsj_1387.out                                            Reports
# 2185  wsj_1387.out                                            Reports
# 2186  wsj_1387.out               were rapidly countered by statements
# 2187  wsj_1387.out                           The JSP admitted Oct. 13
# 2188  wsj_1387.out                           The JSP admitted Oct. 13
# 2189  wsj_1387.out   and charged LDP members with receiving 125 mi...
# 2190  wsj_1387.out   and charged LDP members with receiving 125 mi...
# 2191  wsj_1387.out   On Friday, the chief cabinet secretary announced
# 2192  wsj_1387.out   On Friday, the chief cabinet secretary announced
# 2193  wsj_1387.out   that eight cabinet ministers had received fiv...
# 2194  wsj_1387.out                              including 450,000 yen
# 2195  wsj_1387.out                              including 450,000 yen
# 2196  wsj_1387.out                                 No one has alleged
# 2197  wsj_1387.out                                 No one has alleged
# 2198  wsj_1387.out                                 No one has alleged
# 2199  wsj_1387.out                                 No one has alleged
# 2200  wsj_1387.out                                 No one has alleged
# 2201  wsj_1387.out   Direct donations from either of the residents...
# 2202  wsj_1387.out   Direct donations from either of the residents...
# 2203  wsj_1387.out      but both groups deny making direct donations.
# 2204  wsj_1387.out                                           They say
# 2205  wsj_1387.out                   The issue is further complicated
#
#                                                    EDU2  \
# 0      as GM got early clearance from the Federal Tr...
# 1      as GM got early clearance from the Federal Tr...
# 2      as GM got early clearance from the Federal Tr...
# 3      as GM got early clearance from the Federal Tr...
# 4      as GM got early clearance from the Federal Tr...
# 5      to boost its stake in the British luxury car ...
# 6      that it received permission late Thursday fro...
# 7      that it received permission late Thursday fro...
# 8      that it received permission late Thursday fro...
# 9      to increase its Jaguar holdings past the $15 ...
# 10     that the No. 2 U.S. auto maker had raised its...
# 11     that the No. 2 U.S. auto maker had raised its...
# 12            how many Jaguar shares that company owns.
# 13     and rose five pence to 725 pence ($11.44 Trad...
# 14     and rose five pence to 725 pence ($11.44 Trad...
# 15             and rose five pence to 725 pence ($11.44
# 16                                              ($11.44
# 17     where they closed at $11.625 each, up 62.5 ce...
# 18     that the two U.S. auto giants will move quick...
# 19     setting up a potential bidding war for the pr...
# 20     without government permission. The British go...
# 21     without government permission. The British go...
# 22     without government permission. The British go...
# 23     without government permission. The British go...
# 24                       without government permission.
# 25     which owned Jaguar until 1984, still holds a ...
# 26                       which owned Jaguar until 1984,
# 27      and moved instead to forge an alliance with GM.
# 28     they are close to wrapping up a friendly alli...
# 29     they are close to wrapping up a friendly alli...
# ...                                                 ...
# 2176   as with the Recruit scandal, lists began circ...
# 2177                            who had received money.
# 2178   that members of the ruling LDP had received m...
# 2179   that members of the ruling LDP had received m...
# 2180   that the contributions the LDP members receiv...
# 2181       the LDP members received amounted to bribes.
# 2182                           the LDP members received
# 2183   Reports that Chosen Soren had donated directl...
# 2184   that Chosen Soren had donated directly to JSP...
# 2185   that Chosen Soren had donated directly to JSP...
# 2186   that the South Korean residents' organization...
# 2187   that its members received about eight million...
# 2188   that its members received about eight million...
# 2189   ($880,000 and other opposition parties with t...
# 2190                                          ($880,000
# 2191   that eight cabinet ministers had received fiv...
# 2192   that eight cabinet ministers had received fiv...
# 2193   including 450,000 yen ($3,175 by Prime Minist...
# 2194           ($3,175 by Prime Minister Toshiki Kaifu.
# 2195                                            ($3,175
# 2196   that the donations were by themselves illegal...
# 2197   that the donations were by themselves illegal...
# 2198   that the donations were by themselves illegal...
# 2199   that the donations were by themselves illegal...
# 2200     that the donations were by themselves illegal.
# 2201   because the groups are defined as foreign, bu...
# 2202         because the groups are defined as foreign,
# 2203   They say its possible some of their members m...
# 2204   its possible some of their members may be don...
# 2205   because although the organizations represent ...
#
#                             Relation
# 0                           evidence
# 1                   interpretation-s
# 2                      consequence-s
# 3             elaboration-additional
# 4                       circumstance
# 5     elaboration-object-attribute-e
# 6                           Sequence
# 7                  Inverted-Sequence
# 8                        attribution
# 9     elaboration-object-attribute-e
# 10                        antithesis
# 11                       attribution
# 12                     attribution-n
# 13                Temporal-Same-Time
# 14                     consequence-s
# 15                Temporal-Same-Time
# 16                     restatement-e
# 17          elaboration-additional-e
# 18                       attribution
# 19                     consequence-s
# 20            elaboration-additional
# 21                         summary-n
# 22                      circumstance
# 23            elaboration-additional
# 24                       contingency
# 25                         Same-Unit
# 26          elaboration-additional-e
# 27                          Contrast
# 28            elaboration-additional
# 29                          Contrast
# ...                              ...
# 2176                          manner
# 2177  elaboration-object-attribute-e
# 2178          elaboration-additional
# 2179                     attribution
# 2180  elaboration-object-attribute-e
# 2181                       Same-Unit
# 2182  elaboration-object-attribute-e
# 2183    elaboration-general-specific
# 2184                       Same-Unit
# 2185  elaboration-object-attribute-e
# 2186  elaboration-object-attribute-e
# 2187                            List
# 2188                     attribution
# 2189                       Same-Unit
# 2190                   restatement-e
# 2191                         comment
# 2192                     attribution
# 2193        elaboration-part-whole-e
# 2194                       Same-Unit
# 2195                   restatement-e
# 2196                interpretation-s
# 2197                         comment
# 2198          elaboration-additional
# 2199       explanation-argumentative
# 2200                   attribution-n
# 2201                        Contrast
# 2202       explanation-argumentative
# 2203          elaboration-additional
# 2204                     attribution
# 2205                             NaN
#
# [2206 rows x 4 columns]

# %%
#map all relations to their relation classes
relation_class = {'NaN': 'no relation', 'TextualOrganization' : 'no relation', 'Same-Unit' : 'no relation', 'attribution-e' : 'attribution', 'attribution' : 'attribution', 'attribution-n' : 'attribution', 'Cause-Result':'cause', 'attribution-negative':'attribution','background':'background', 'background-e' : 'background', 'circumstance' : 'background', 'circumstance-e' :'background', 'cause' : 'cause', 'result' : 'cause', 'result-e' : 'cause', 'Consequence' : 'cause', 'consequence-n': 'cause', 'consequence-s' : 'cause','consequence-n-e' :'cause', 'consequence-s-e': 'cause', 'Comparison' : 'comparison', 'comparison' :'comparison', 'comparison-e': 'comparison', 'preference': 'comparison','preference-e': 'comparison', 'analogy' : 'comparison', 'analogy-e': 'comparison', 'Analogy': 'comparison', 'Proportion' : 'comparison','condition' : 'condition', 'condition-e' : 'condition', 'hypothetical' : 'condition', 'contingency' : 'condition', 'otherwise': 'condition', 'Otherwise' : 'condition', 'Contrast' : 'contrast', 'concession': 'contrast', 'concession-e' : 'contrast', 'antithesis' : 'contrast', 'antithesis-e': 'contrast', 'elaboration-additional' : 'elaboration', 'elaboration-additional-e' : 'elaboration', 'elaboration-general-specific' : 'elaboration', 'elaboration-general-specific-e' : 'elaboration', 'elaboration-object-attribute' :'elaboration', 'elaboration-part-whole' : 'elaboration', 'elaboration-part-whole-e' : 'elaboration','definition-e': 'elaboration', 'elaboration-process-step-e' : 'elaboration', 'elaboration-process-step' : 'elaboration', 'elaboration-object-attribute-e' : 'elaboration', 'elaboration-set-member' : 'elaboration', 'elaboration-set-member-e' :'elaboration', 'example' : 'elaboration','example-e' : 'elaboration', 'definition' : 'elaboration',  'purpose-e': 'enablement', 'enablement-e': 'enablement', 'purpose' : 'enablement', 'enablement' : 'enablement', 'evaluation' : 'evaluation', 'evaluation-s' : 'evaluation', 'evaluation-n' : 'evaluation', 'Evaluation': 'evaluation', 'Interpretation' :'evaluation', 'interpretation-s-e' : 'evaluation',  'interpretation-s': 'evaluation', 'interpretation-n' : 'evaluation', 'conclusion' : 'evaluation', 'evaluation-s-e': 'evaluation', 'comment' : 'evaluation', 'comment-e' : 'evaluation', 'evidence': 'explanation', 'explanation-argumentative' : 'explanation', 'explanation-argumentative-e': 'explanation', 'Reason': 'explanation', 'reason-e' : 'explanation', 'reason' : 'explanation','evidence-e': 'explanation', 'List' : 'joint', 'Disjunction' : 'joint', 'manner' : 'manner-means', 'manner-e' : 'manner-means', 'means-e': 'manner-means', 'means' : 'manner-means','Problem-Solution' : 'topic-comment', 'problem-solution-e': 'topic-comment', 'problem-solution-s': 'topic-comment', 'problem-solution-n': 'topic-comment', 'problem-solution-n' : 'topic-comment', 'Topic-Comment': 'topic-comment', 'summary-n' : 'summary', 'summary-s' : 'summary', 'question-answer-s' : 'topic-comment', 'question-answer-n': 'topic-comment', 'Question-Answer' : 'topic-comment', 'Statement-Response' : 'topic-comment', 'Topic-Comment' :'topic-comment', 'rhetorical-question' : 'topic-comment', 'restatement-e' : 'summary','Comment-Topic': 'topic-comment', 'statement-response-n': 'topic-comment', 'statement-response-s': 'topic-comment', 'statement-response-e': 'topic-comment',  'restatement': 'summary',  'temporal-before' : 'temporal', 'temporal-after' : 'temporal', 'temporal-after-e' : 'temporal', 'Temporal-Same-Time' : 'temporal', 'temporal-same-time' :'temporal', 'temporal-same-time-e' : 'temporal', 'Sequence' : 'temporal', 'Inverted-Sequence' : 'temporal', 'Topic-Shift' : 'topic-change', 'Topic-Drift' : 'topic-change', 'topic-drift': 'topic-change', 'temporal-before-e': 'temporal', 'topic-drift-e': 'topic-change', 'topic-shift': 'topic-change'}

#set the relation classes
df["Relation Class"] = df["Relation"].map(relation_class)

#export the preprocessed data to a csv file
export_csv = df.to_csv (r'processed_training_data-f.csv', index = None, header=True, sep = '|')

df
# Out:
#           Filename                                               EDU1  \
# 0     wsj_0632.out   General Motors Corp. and Ford Motor Co. are n...
# 1     wsj_0632.out   General Motors Corp. and Ford Motor Co. are n...
# 2     wsj_0632.out   General Motors Corp. and Ford Motor Co. are n...
# 3     wsj_0632.out   General Motors Corp. and Ford Motor Co. are n...
# 4     wsj_0632.out   General Motors Corp. and Ford Motor Co. are n...
# 5     wsj_0632.out   as GM got early clearance from the Federal Tr...
# 6     wsj_0632.out                                GM confirmed Friday
# 7     wsj_0632.out                                GM confirmed Friday
# 8     wsj_0632.out                                GM confirmed Friday
# 9     wsj_0632.out   that it received permission late Thursday fro...
# 10    wsj_0632.out                    and on Friday, Jaguar announced
# 11    wsj_0632.out                    and on Friday, Jaguar announced
# 12    wsj_0632.out   A spokesman for GM, the No. 1 auto maker, dec...
# 13    wsj_0632.out   In late trading Friday, Jaguar shares bucked ...
# 14    wsj_0632.out   In late trading Friday, Jaguar shares bucked ...
# 15    wsj_0632.out   In late trading Friday, Jaguar shares bucked ...
# 16    wsj_0632.out                   and rose five pence to 725 pence
# 17    wsj_0632.out   In the U.S., Jaguar's American depositary rec...
# 18    wsj_0632.out                                    Analysts expect
# 19    wsj_0632.out   that the two U.S. auto giants will move quick...
# 20    wsj_0632.out   British government restrictions prevent any s...
# 21    wsj_0632.out   British government restrictions prevent any s...
# 22    wsj_0632.out   British government restrictions prevent any s...
# 23    wsj_0632.out   British government restrictions prevent any s...
# 24    wsj_0632.out   British government restrictions prevent any s...
# 25    wsj_0632.out                            The British government,
# 26    wsj_0632.out                            The British government,
# 27    wsj_0632.out   With the golden share as protection, Jaguar o...
# 28    wsj_0632.out                    Jaguar officials have indicated
# 29    wsj_0632.out                    Jaguar officials have indicated
# ...            ...                                                ...
# 2176  wsj_1387.out                       But the press kept it alive;
# 2177  wsj_1387.out   as with the Recruit scandal, lists began circ...
# 2178  wsj_1387.out   Within a matter of weeks, less-conservative m...
# 2179  wsj_1387.out   Within a matter of weeks, less-conservative m...
# 2180  wsj_1387.out     So far, though, there have been no allegations
# 2181  wsj_1387.out                             that the contributions
# 2182  wsj_1387.out                             that the contributions
# 2183  wsj_1387.out                 Then the two camps upped the ante:
# 2184  wsj_1387.out                                            Reports
# 2185  wsj_1387.out                                            Reports
# 2186  wsj_1387.out               were rapidly countered by statements
# 2187  wsj_1387.out                           The JSP admitted Oct. 13
# 2188  wsj_1387.out                           The JSP admitted Oct. 13
# 2189  wsj_1387.out   and charged LDP members with receiving 125 mi...
# 2190  wsj_1387.out   and charged LDP members with receiving 125 mi...
# 2191  wsj_1387.out   On Friday, the chief cabinet secretary announced
# 2192  wsj_1387.out   On Friday, the chief cabinet secretary announced
# 2193  wsj_1387.out   that eight cabinet ministers had received fiv...
# 2194  wsj_1387.out                              including 450,000 yen
# 2195  wsj_1387.out                              including 450,000 yen
# 2196  wsj_1387.out                                 No one has alleged
# 2197  wsj_1387.out                                 No one has alleged
# 2198  wsj_1387.out                                 No one has alleged
# 2199  wsj_1387.out                                 No one has alleged
# 2200  wsj_1387.out                                 No one has alleged
# 2201  wsj_1387.out   Direct donations from either of the residents...
# 2202  wsj_1387.out   Direct donations from either of the residents...
# 2203  wsj_1387.out      but both groups deny making direct donations.
# 2204  wsj_1387.out                                           They say
# 2205  wsj_1387.out                   The issue is further complicated
#
#                                                    EDU2  \
# 0      as GM got early clearance from the Federal Tr...
# 1      as GM got early clearance from the Federal Tr...
# 2      as GM got early clearance from the Federal Tr...
# 3      as GM got early clearance from the Federal Tr...
# 4      as GM got early clearance from the Federal Tr...
# 5      to boost its stake in the British luxury car ...
# 6      that it received permission late Thursday fro...
# 7      that it received permission late Thursday fro...
# 8      that it received permission late Thursday fro...
# 9      to increase its Jaguar holdings past the $15 ...
# 10     that the No. 2 U.S. auto maker had raised its...
# 11     that the No. 2 U.S. auto maker had raised its...
# 12            how many Jaguar shares that company owns.
# 13     and rose five pence to 725 pence ($11.44 Trad...
# 14     and rose five pence to 725 pence ($11.44 Trad...
# 15             and rose five pence to 725 pence ($11.44
# 16                                              ($11.44
# 17     where they closed at $11.625 each, up 62.5 ce...
# 18     that the two U.S. auto giants will move quick...
# 19     setting up a potential bidding war for the pr...
# 20     without government permission. The British go...
# 21     without government permission. The British go...
# 22     without government permission. The British go...
# 23     without government permission. The British go...
# 24                       without government permission.
# 25     which owned Jaguar until 1984, still holds a ...
# 26                       which owned Jaguar until 1984,
# 27      and moved instead to forge an alliance with GM.
# 28     they are close to wrapping up a friendly alli...
# 29     they are close to wrapping up a friendly alli...
# ...                                                 ...
# 2176   as with the Recruit scandal, lists began circ...
# 2177                            who had received money.
# 2178   that members of the ruling LDP had received m...
# 2179   that members of the ruling LDP had received m...
# 2180   that the contributions the LDP members receiv...
# 2181       the LDP members received amounted to bribes.
# 2182                           the LDP members received
# 2183   Reports that Chosen Soren had donated directl...
# 2184   that Chosen Soren had donated directly to JSP...
# 2185   that Chosen Soren had donated directly to JSP...
# 2186   that the South Korean residents' organization...
# 2187   that its members received about eight million...
# 2188   that its members received about eight million...
# 2189   ($880,000 and other opposition parties with t...
# 2190                                          ($880,000
# 2191   that eight cabinet ministers had received fiv...
# 2192   that eight cabinet ministers had received fiv...
# 2193   including 450,000 yen ($3,175 by Prime Minist...
# 2194           ($3,175 by Prime Minister Toshiki Kaifu.
# 2195                                            ($3,175
# 2196   that the donations were by themselves illegal...
# 2197   that the donations were by themselves illegal...
# 2198   that the donations were by themselves illegal...
# 2199   that the donations were by themselves illegal...
# 2200     that the donations were by themselves illegal.
# 2201   because the groups are defined as foreign, bu...
# 2202         because the groups are defined as foreign,
# 2203   They say its possible some of their members m...
# 2204   its possible some of their members may be don...
# 2205   because although the organizations represent ...
#
#                             Relation Relation Class
# 0                           evidence    explanation
# 1                   interpretation-s     evaluation
# 2                      consequence-s          cause
# 3             elaboration-additional    elaboration
# 4                       circumstance     background
# 5     elaboration-object-attribute-e    elaboration
# 6                           Sequence       temporal
# 7                  Inverted-Sequence       temporal
# 8                        attribution    attribution
# 9     elaboration-object-attribute-e    elaboration
# 10                        antithesis       contrast
# 11                       attribution    attribution
# 12                     attribution-n    attribution
# 13                Temporal-Same-Time       temporal
# 14                     consequence-s          cause
# 15                Temporal-Same-Time       temporal
# 16                     restatement-e        summary
# 17          elaboration-additional-e    elaboration
# 18                       attribution    attribution
# 19                     consequence-s          cause
# 20            elaboration-additional    elaboration
# 21                         summary-n        summary
# 22                      circumstance     background
# 23            elaboration-additional    elaboration
# 24                       contingency      condition
# 25                         Same-Unit    no relation
# 26          elaboration-additional-e    elaboration
# 27                          Contrast       contrast
# 28            elaboration-additional    elaboration
# 29                          Contrast       contrast
# ...                              ...            ...
# 2176                          manner   manner-means
# 2177  elaboration-object-attribute-e    elaboration
# 2178          elaboration-additional    elaboration
# 2179                     attribution    attribution
# 2180  elaboration-object-attribute-e    elaboration
# 2181                       Same-Unit    no relation
# 2182  elaboration-object-attribute-e    elaboration
# 2183    elaboration-general-specific    elaboration
# 2184                       Same-Unit    no relation
# 2185  elaboration-object-attribute-e    elaboration
# 2186  elaboration-object-attribute-e    elaboration
# 2187                            List          joint
# 2188                     attribution    attribution
# 2189                       Same-Unit    no relation
# 2190                   restatement-e        summary
# 2191                         comment     evaluation
# 2192                     attribution    attribution
# 2193        elaboration-part-whole-e    elaboration
# 2194                       Same-Unit    no relation
# 2195                   restatement-e        summary
# 2196                interpretation-s     evaluation
# 2197                         comment     evaluation
# 2198          elaboration-additional    elaboration
# 2199       explanation-argumentative    explanation
# 2200                   attribution-n    attribution
# 2201                        Contrast       contrast
# 2202       explanation-argumentative    explanation
# 2203          elaboration-additional    elaboration
# 2204                     attribution    attribution
# 2205                             NaN            NaN
#
# [2206 rows x 5 columns]

# %%
#view counts of all the relation classes 
print(df['Relation Class'].value_counts())
# Out:
# elaboration      796
# attribution      343
# contrast         146
# joint            140
# no relation      133
# background       111
# explanation      110
# cause             82
# evaluation        80
# temporal          68
# condition         48
# enablement        46
# summary           32
# comparison        29
# manner-means      27
# topic-comment     24
# topic-change       7
# Name: Relation Class, dtype: int64
