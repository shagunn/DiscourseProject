# %%
import glob
import os
import re

import numpy as np
import pandas as pd

import spacy
spacy.load('en')
from spacy.lang.en import English

# %%
path = 'rst_discourse_treebank/data/RSTtrees-WSJ-main-1.0/TRAINING/'

# %%
""" Load Data
    
    Outputs
    ----------
    data_list : list within list
        outer list contains documents
        inner list contains edus in each document
        [[edu_0, edu_1],[edu_0, edu_1]]
    
    edu_filenames : filenames corresponeding to outer list of data_list

"""

filename_list = []
data_list = []
innerlist = []

# define desired replacements here
rep = {'"': '', '(': '', ')':'', '. . .':' ', '**':'', 
       'Prof.':'Prof', '-- ':'', 'Alex. Brown & Sons':'Alex-Brown & Sons', 'No.':'number', 'G.m.b. H.':'GmbH',
       'Canada First!':'Canada First', 'Cos.':'Companies', 'Sens.':'Senators', 'Col.':'Colonel','Prop.':'Proposition',
       '` The Art of the Deal.':'\'The Art of the Deal.\'','\' Why doesn':'Why doesn',
       '`dolce! dolce!\' {`sweet! sweet!\'}.':'\'dolce dolce sweet sweet\'', 'S.p. A.':'SpA', 'Pty.':'Proprietary',
       'Westamerica Bancorp.':'Westamerica Bancorporation', 'Ing. C. Olivetti & Co.':'Olivetti SpA',
       'Tex.':'Texas', 'Cie.':'Compagnie', 'Sept. 30-Oct. 4':'Sept. 30-October 4', 
       'Mort! Mort! Mort!':'\'Mort Mort Mort\'',
       '1. Use':'Use', '2. Provide':'Provide','3. Record':'Record', '4. Impose':'Impose',
      '1. As part':'As part', '2. In seeking':'In seeking', '3. In deciding':'In deciding', '4. When a RICO':'When a RICO'} 
rep = dict((re.escape(k), v) for k, v in rep.items())
pattern = re.compile("|".join(rep.keys()))

# for each file in path folder
for filename in glob.glob(os.path.join(path, '*.edus')):
    filename_list.append(filename)
    # open file
    with open(filename) as my_file: 
        for line in my_file:
            text = line
            if ("contributed to this article") in text or ("Year ago figure is restated" in text):
                continue
            text = pattern.sub(lambda m: rep[re.escape(m.group(0))], text)
#             innerlist.append(((line.lstrip()).rstrip()).replace('"',''))
#             innerlist.append((line.lstrip()).rstrip())
            innerlist.append((text.lstrip()).rstrip())
    data_list.append(innerlist)
    innerlist = []
    
edu_filenames = [s.strip('rst_discourse_treebank/data/RSTtrees-WSJ-main-1.0/TRAINING/') for s in filename_list]

# %%
print("Files processed: ", len(edu_filenames))
print("Data length: ", len(data_list))
# Out:
# Files processed:  347
# Data length:  347

# %%
# See Example
print(edu_filenames[1])
data_list[1]
# Out:
# wsj_0668
# ['ABB Asea Brown Boveri B.V. said',
#  'it signed a contract for the largest-ever power plant order in the Netherlands.',
#  'ABB said',
#  'the contract,',
#  'signed with the Dutch utility N.V. Energieproduktiebedrijf UNA,',
#  'is valued in excess of $200 million.',
#  'The accord is for a turbogenerator plant at the coal-fired power station Hemweg in Amsterdam.',
#  'ABB Asea Brown Boveri is the Dutch unit of the Swedish-Swiss electrical engineering group ABB Asea Brown Boveri AG.',
#  'ABB said',
#  'a significant portion of the order will be placed with Dutch subcontractors,',
#  'adding',
#  'that a group has been set up for this purpose.',
#  'The Dutch utility firm serves the Amsterdam and Utrecht areas.',
#  'The planned turbogenerator plant is expected to go into operation in 1994.']

# %%
' '.join(data_list[1])
# Out:
# 'ABB Asea Brown Boveri B.V. said it signed a contract for the largest-ever power plant order in the Netherlands. ABB said the contract, signed with the Dutch utility N.V. Energieproduktiebedrijf UNA, is valued in excess of $200 million. The accord is for a turbogenerator plant at the coal-fired power station Hemweg in Amsterdam. ABB Asea Brown Boveri is the Dutch unit of the Swedish-Swiss electrical engineering group ABB Asea Brown Boveri AG. ABB said a significant portion of the order will be placed with Dutch subcontractors, adding that a group has been set up for this purpose. The Dutch utility firm serves the Amsterdam and Utrecht areas. The planned turbogenerator plant is expected to go into operation in 1994.'

# %%
""" For each document --> converts edus in each document to paragraphs, then sentences
    
    Outputs
    ----------
    data_sentences : list within list
        outer list contains documents
        inner list contains the sentences in each document
        [[sentence_1, sentence_1],[sentence_0, sentence_1]]
"""
nlp = English()
nlp.add_pipe(nlp.create_pipe('sentencizer'))
# doc = nlp('Iterate over the sentences in the document. Sentence spans have no label. To improve accuracy on informal texts, spaCy calculates sentence boundaries from the syntactic dependency parse. If the parser is disabled, the sents iterator will be unavailable.')
# https://github.com/explosion/spaCy/issues/2708

data_sentences = []
for document in data_list:
    doc = nlp(' '.join(document))
    doc_sentences = []
    for sent in doc.sents:
        doc_sentences.append(sent.text)
    data_sentences.append(doc_sentences)

# %%
len(data_sentences)
# Out:
# 347

# %%
""" For each document --> get list of edus/sentence
    
    Outputs
    ----------
    data_doc_edus : list within list within list
        outer list contains documents
        middle list contains the sentences in each document
        inner list contains edus in each sentence 
        [document1[sentence1[edu_0, edu_1],sentence2[edu_0, edu_1]], document2[[],[]]]
"""
doc_counter = 0
sent_counter = 0
data_doc_edus = []
notworking_counter = 0
listdidntwork = []
for doc_counter, doc in enumerate(data_sentences):
#     print("------------------- DOCUMENT: ", doc_counter, " -------------------")
#     print(" ")
    edus_in_doc = data_list[doc_counter].copy()
    doc_edus = []
    for sent_counter, sentence in enumerate(doc):
        didntwork = False            
#         print('SENTENCE ',sent_counter,': ',sentence)
#         print(" ")
        edu_check = []
        edu_counter = 0
        for edu_counter, edu in enumerate(edus_in_doc):
            edu_check.append(edu)
            if ' '.join(edu_check) == sentence:
                for item in edu_check:
                    edus_in_doc.remove(item)
#                     print('SENTENCE:', edu_counter, item)
#                 print(edu_check)
                doc_edus.append(edu_check)
                break
            if edu_counter == (len(edus_in_doc)-1):
#                 print("ALL EDUS CONSIDERED")
                didntwork = True
                notworking_counter+=1
        if sentence.endswith('"'):
            listdidntwork.append([sent_counter, sentence, didntwork])
#         print(" ")
#         print(" ")
    data_doc_edus.append(doc_edus)

# %%
notworking_counter
# Out:
# 0

# %%
len(data_doc_edus)
# Out:
# 347

# %%
sentence_counter = 0
document_counter = 0
row_data = []
document_testing = []
for document_counter, document in enumerate(data_doc_edus):
    for sentence_counter, sent in enumerate(document):
        for first, second in zip(sent, sent[1:]):
            document_testing.append(document_counter)
            row_data.append([edu_filenames[document_counter],document_counter, sentence_counter, first, second])

# %%
headers = ['File','Document', 'Sentence', 'EDU1', 'EDU2']

# %%
df_data = pd.DataFrame(row_data, columns=headers)
df_data
# Out:
#            File  Document  Sentence  \
# 0      wsj_0669         0         0
# 1      wsj_0669         0         0
# 2      wsj_0669         0         0
# 3      wsj_0669         0         1
# 4      wsj_0669         0         1
# 5      wsj_0669         0         1
# 6      wsj_0669         0         2
# 7      wsj_0669         0         2
# 8      wsj_0669         0         2
# 9      wsj_0669         0         2
# 10     wsj_0669         0         3
# 11     wsj_0669         0         3
# 12     wsj_0669         0         3
# 13     wsj_0669         0         4
# 14     wsj_0669         0         4
# 15     wsj_0669         0         4
# 16     wsj_0669         0         5
# 17     wsj_0669         0         5
# 18     wsj_0669         0         6
# 19     wsj_0669         0         6
# 20     wsj_0669         0         6
# 21     wsj_0669         0         7
# 22     wsj_0669         0         7
# 23     wsj_0668         1         0
# 24     wsj_0668         1         1
# 25     wsj_0668         1         1
# 26     wsj_0668         1         1
# 27     wsj_0668         1         4
# 28     wsj_0668         1         4
# 29     wsj_0668         1         4
# ...         ...       ...       ...
# 12053  wsj_1102       345        13
# 12054  wsj_1102       345        13
# 12055  wsj_1102       345        14
# 12056  wsj_1102       345        15
# 12057  wsj_1102       345        16
# 12058  wsj_1102       345        17
# 12059  wsj_1102       345        19
# 12060  wsj_1102       345        20
# 12061  wsj_1102       345        22
# 12062  wsj_1102       345        22
# 12063  wsj_1102       345        22
# 12064  wsj_1102       345        22
# 12065  wsj_1102       345        23
# 12066  wsj_1102       345        23
# 12067  wsj_1102       345        23
# 12068  wsj_1102       345        24
# 12069  wsj_1102       345        25
# 12070  wsj_0645       346         0
# 12071  wsj_0645       346         0
# 12072  wsj_0645       346         0
# 12073  wsj_0645       346         1
# 12074  wsj_0645       346         1
# 12075  wsj_0645       346         1
# 12076  wsj_0645       346         2
# 12077  wsj_0645       346         3
# 12078  wsj_0645       346         3
# 12079  wsj_0645       346         4
# 12080  wsj_0645       346         4
# 12081  wsj_0645       346         5
# 12082  wsj_0645       346         5
#
#                                                     EDU1  \
# 0      Nissan Motor Co. expects net income to reach 1...
# 1                                      U.S. $857 million
# 2      in its current fiscal year, up from 114.6 bill...
# 3      Mr. Kume made the earnings projection for fisc...
# 4                                  ending next March 31,
# 5           in an interview with U.S. automotive writers
# 6                                     The executive said
# 7      that the anticipated earnings increase is fair...
# 8                     because Nissan is spending heavily
# 9             to bolster its dealership network in Japan
# 10                               During the next decade,
# 11                                        Mr. Kume said,
# 12     Nissan plans to boost overseas vehicle product...
# 13                                            Last year,
# 14                                        Mr. Kume said,
# 15     Nissan exported slightly over one million vehi...
# 16                                          But by 1992,
# 17                                             he added,
# 18                              By the end of the 1990s,
# 19                                              he said,
# 20     we want to be producing roughly two vehicles o...
# 21     That will involve a substantial increase in ov...
# 22                                      he acknowledged,
# 23                       ABB Asea Brown Boveri B.V. said
# 24                                              ABB said
# 25                                         the contract,
# 26     signed with the Dutch utility N.V. Energieprod...
# 27                                              ABB said
# 28     a significant portion of the order will be pla...
# 29                                                adding
# ...                                                  ...
# 12053            that the dollar is now moving sideways,
# 12054                                             adding
# 12055  Analysts peg the dollar's recent weakness to a...
# 12056                                They also point out
# 12057          Despite several spurts of dollar trading,
# 12058                 Following the dive in U.S. stocks,
# 12059                                      But, they add
# 12060                              The question remains:
# 12061                                   Some dealers say
# 12062  that Bank of Japan Governor Satoshi Sumita's r...
# 12063  that Japanese monetary policy won't be changed...
# 12064                has given investors an added excuse
# 12065  Despite the yen's weakness with respect to the...
# 12066                                  Tokyo traders say
# 12067  they don't expect the Bank of Japan to take an...
# 12068                Meanwhile, sterling slumped on news
# 12069  The news also knocked the British unit to belo...
# 12070  Merger and acquisition activity in the third q...
# 12071  said Merrill Lynch & Co. 's W.T. Grimm & Co. u...
# 12072  A total of 672 transactions were announced dur...
# 12073                                       Transactions
# 12074                     in which prices were disclosed
# 12075  totaled $71.9 billion, up 36% from $52.9 billi...
# 12076                      Grimm counted 16 transactions
# 12077             The largest was the $12 billion merger
# 12078                  creating Bristol-Myers Squibb Co.
# 12079                                       Transactions
# 12080                     in which prices were disclosed
# 12081  Citing current stock market conditions and the...
# 12082                                         Grimm said
#
#                                                     EDU2
# 0                                      U.S. $857 million
# 1      in its current fiscal year, up from 114.6 bill...
# 2                          Yutaka Kume, president, said.
# 3                                  ending next March 31,
# 4           in an interview with U.S. automotive writers
# 5                        attending the Tokyo Motor Show.
# 6      that the anticipated earnings increase is fair...
# 7                     because Nissan is spending heavily
# 8             to bolster its dealership network in Japan
# 9         and because of currency-exchange fluctuations.
# 10                                        Mr. Kume said,
# 11     Nissan plans to boost overseas vehicle product...
# 12     to account for a majority of sales outside Japan.
# 13                                        Mr. Kume said,
# 14     Nissan exported slightly over one million vehi...
# 15     and produced 570,000 cars and trucks at its fa...
# 16                                             he added,
# 17     Nissan will build one million vehicles a year ...
# 18                                              he said,
# 19     we want to be producing roughly two vehicles o...
# 20                            that we export from Japan.
# 21                                      he acknowledged,
# 22                  but didn't provide specific details.
# 23     it signed a contract for the largest-ever powe...
# 24                                         the contract,
# 25     signed with the Dutch utility N.V. Energieprod...
# 26                  is valued in excess of $200 million.
# 27     a significant portion of the order will be pla...
# 28                                                adding
# 29        that a group has been set up for this purpose.
# ...                                                  ...
# 12053                                             adding
# 12054  that the next leg could be the beginning of a ...
# 12055  highlighted by recent economic data, particula...
# 12056  that narrowing interest-rate differentials bet...
# 12057  it was noted that mark-yen cross trade grabbed...
# 12058  the mark has strengthened more than its major ...
# 12059  that the mark's strength is in part a reflecti...
# 12060        how much can the West German market absorb?
# 12061  that Bank of Japan Governor Satoshi Sumita's r...
# 12062  that Japanese monetary policy won't be changed...
# 12063                has given investors an added excuse
# 12064  to push the yen down even further against the ...
# 12065                                  Tokyo traders say
# 12066  they don't expect the Bank of Japan to take an...
# 12067    to support the Japanese currency on that front.
# 12068  that the United Kingdom posted a wider-than-ex...
# 12069  but a bout of short-covering helped sterling r...
# 12070  said Merrill Lynch & Co. 's W.T. Grimm & Co. u...
# 12071  A total of 672 transactions were announced dur...
# 12072                                        Grimm said.
# 12073                     in which prices were disclosed
# 12074  totaled $71.9 billion, up 36% from $52.9 billi...
# 12075                                 the company added.
# 12076  valued at $1 billion or more in the latest per...
# 12077                  creating Bristol-Myers Squibb Co.
# 12078  In the first nine months, 1,977 transactions w...
# 12079                     in which prices were disclosed
# 12080  totaled $188.1 billion, up 15% from $163.2 bil...
# 12081                                         Grimm said
# 12082  it wasn't certain that the total value of tran...
#
# [12083 rows x 5 columns]

# %%
df_data.to_csv('EDU_pairs_TRAINING.csv', index=False)

# %% [markdown]
# #### Load Data/Corpus Statistics

# %%
results = pd.read_csv('EDU_pairs_TRAINING.csv')

# %%
newdf = results.loc[results.Document == 1]

# %%
newdf.reset_index(drop=True)
# Out:
#        File  Document  Sentence  \
# 0  wsj_0668         1         0
# 1  wsj_0668         1         1
# 2  wsj_0668         1         1
# 3  wsj_0668         1         1
# 4  wsj_0668         1         4
# 5  wsj_0668         1         4
# 6  wsj_0668         1         4
#
#                                                 EDU1  \
# 0                    ABB Asea Brown Boveri B.V. said
# 1                                           ABB said
# 2                                      the contract,
# 3  signed with the Dutch utility N.V. Energieprod...
# 4                                           ABB said
# 5  a significant portion of the order will be pla...
# 6                                             adding
#
#                                                 EDU2
# 0  it signed a contract for the largest-ever powe...
# 1                                      the contract,
# 2  signed with the Dutch utility N.V. Energieprod...
# 3               is valued in excess of $200 million.
# 4  a significant portion of the order will be pla...
# 5                                             adding
# 6     that a group has been set up for this purpose.

# %%
"ABB Asea Brown Boveri B.V. said it signed a contract for the largest-ever power plant order in the Netherlands."
"ABB said the contract, signed with the Dutch utility N.V. Energieproduktiebedrijf UNA, is valued in excess of $200 million."
"The accord is for a turbogenerator plant at the coal-fired power station Hemweg in Amsterdam." 
"ABB Asea Brown Boveri is the Dutch unit of the Swedish-Swiss electrical engineering group ABB Asea Brown Boveri AG." 
"ABB said a significant portion of the order will be placed with Dutch subcontractors, adding that a group has been set up for this purpose." 
"The Dutch utility firm serves the Amsterdam and Utrecht areas. "
"The planned turbogenerator plant is expected to go into operation in 1994."
# Out:
# 'The Dutch utility firm serves the Amsterdam and Utrecht areas. The planned turbogenerator plant is expected to go into operation in 1994.'

# %%
results.File.describe()
# Out:
# count       12083
# unique        308
# top       wsj_116
# freq          187
# Name: File, dtype: object

# %%
results.Sentence.describe()
# Out:
# count    12083.000000
# mean        18.720930
# std         17.679687
# min          0.000000
# 25%          5.000000
# 50%         14.000000
# 75%         27.000000
# max        101.000000
# Name: Sentence, dtype: float64

# %%
len(results.Document.unique())
# Out:
# 342

# %%
len(results.Document.unique())
# Out:
# 342

# %%
alldocs = list(np.arange(347))

# %%
docsinfinal = list(set(document_testing))

# %%
len(docsinfinal)
# Out:
# 342

# %%
docs_not_in_final = [item for item in alldocs if item not in docsinfinal]

# %%
for fileix in docs_not_in_final:
    print(edu_filenames[fileix])
# Out:
# wsj_1132
# wsj_1117
# wsj_1369
# wsj_1127
# wsj_118
